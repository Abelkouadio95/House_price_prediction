# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('/content/drive/MyDrive/Dataset/Canada.xlsx')
df.head()
# Out:
#             Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                  NaN        NaN        NaN        NaN        NaN        NaN
# 1                  NaN        NaN        NaN        NaN        NaN        NaN
# 2                  NaN        NaN        NaN        NaN        NaN        NaN
# 3       United Nations        NaN        NaN        NaN        NaN        NaN
# 4  Population Division        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 28 Unnamed: 29  \
# 0        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 1        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 2        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 3        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 4        NaN        NaN        NaN        NaN  ...         NaN         NaN
#
# ...

# %%
#df.drop( [0:19], axis=0, inplace=True)
df.drop(df.index[0:19], inplace=True)
df.head()
# Out:
#     Unnamed: 0  Unnamed: 1        Unnamed: 2        Unnamed: 3 Unnamed: 4  \
# 19        Type    Coverage          AreaName           RegName       1980
# 20  Immigrants    Citizens  Northern America  Northern America         ..
# 21  Immigrants  Foreigners            Africa    Eastern Africa       1471
# 22  Immigrants  Foreigners            Africa     Middle Africa         33
# 23  Immigrants  Foreigners            Africa   Northern Africa       1100
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 28  \
# 19       1981       1982       1983       1984       1985  ...        2004
# 20         ..         ..         ..         ..         ..  ...          ..
# 21       1641       1426       1094       1187       1134  ...        7726
# 22         27         44         32         42         30  ...        2452
# 23       1268       1348        936        842        840  ...       12478
#
# ...

# %%
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#    Unnamed: 0  Unnamed: 1        Unnamed: 2        Unnamed: 3 Unnamed: 4  \
# 0        Type    Coverage          AreaName           RegName       1980
# 1  Immigrants    Citizens  Northern America  Northern America         ..
# 2  Immigrants  Foreigners            Africa    Eastern Africa       1471
# 3  Immigrants  Foreigners            Africa     Middle Africa         33
# 4  Immigrants  Foreigners            Africa   Northern Africa       1100
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 28  \
# 0       1981       1982       1983       1984       1985  ...        2004
# 1         ..         ..         ..         ..         ..  ...          ..
# 2       1641       1426       1094       1187       1134  ...        7726
# 3         27         44         32         42         30  ...        2452
# 4       1268       1348        936        842        840  ...       12478
#
#   Unnamed: 29 Unnamed: 30 Unnamed: 31 Unnamed: 32 Unnamed: 33 Unnamed: 34  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25',
#        'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29',
#        'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33',
#        'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37'],
#       dtype='object')

# %%
for i in df.columns:
  df.rename(columns={i:df.loc[0,i]}, inplace=True)
df.head()
# Out:
#          Type    Coverage          AreaName           RegName  1980  1981  \
# 0        Type    Coverage          AreaName           RegName  1980  1981
# 1  Immigrants    Citizens  Northern America  Northern America    ..    ..
# 2  Immigrants  Foreigners            Africa    Eastern Africa  1471  1641
# 3  Immigrants  Foreigners            Africa     Middle Africa    33    27
# 4  Immigrants  Foreigners            Africa   Northern Africa  1100  1268
#
#    1982  1983  1984  1985  ...   2004   2005   2006   2007   2008   2009  \
# 0  1982  1983  1984  1985  ...   2004   2005   2006   2007   2008   2009
# 1    ..    ..    ..    ..  ...     ..     ..     ..     ..     ..     ..
# 2  1426  1094  1187  1134  ...   7726   7083   6750   6669   6705   6922
# 3    44    32    42    30  ...   2452   2802   2834   2951   3034   3255
# 4  1348   936   842   840  ...  12478  11323  12705  11750  13456  16320
#
#     2010   2011   2012.0  2013.0
# 0   2010   2011   2012.0  2013.0
# ...

# %%
df.drop(0, axis=0, inplace=True)
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#          Type    Coverage          AreaName           RegName  1980  1981  \
# 0  Immigrants    Citizens  Northern America  Northern America    ..    ..
# 1  Immigrants  Foreigners            Africa    Eastern Africa  1471  1641
# 2  Immigrants  Foreigners            Africa     Middle Africa    33    27
# 3  Immigrants  Foreigners            Africa   Northern Africa  1100  1268
# 4  Immigrants  Foreigners            Africa   Southern Africa  1041  1126
#
#    1982  1983  1984  1985  ...   2004   2005   2006   2007   2008   2009  \
# 0    ..    ..    ..    ..  ...     ..     ..     ..     ..     ..     ..
# 1  1426  1094  1187  1134  ...   7726   7083   6750   6669   6705   6922
# 2    44    32    42    30  ...   2452   2802   2834   2951   3034   3255
# 3  1348   936   842   840  ...  12478  11323  12705  11750  13456  16320
# 4   791   387   297   327  ...   1203   1012   1148   1230   1184   1235
#
#     2010   2011   2012.0  2013.0
# 0     ..      1      1.0     NaN
# ...

# %%
df['Coverage'].unique()
# Out:
# array(['Citizens', 'Foreigners'], dtype=object)

# %%
plt.figure(figsize=(10,3))
sns.countplot(x='Coverage', data=df)
# Out:
# <Axes: xlabel='Coverage', ylabel='count'>
